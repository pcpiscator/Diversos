# %% [markdown]
# <a href="https://colab.research.google.com/github/pcpiscator/Diversos/blob/main/pipelines_de_ETL_e_ELT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

def extract(file_name):
    print(f"Extracting data from {"raw_data.csv"}")
    return pd.read_csv("raw_data.csv")

# %%
# Create a dummy raw_data.csv file for demonstration
import pandas as pd
dummy_data = {'col1': [1, 2, 3], 'col2': ['A', 'B', 'C']}
dummy_df = pd.DataFrame(dummy_data)
dummy_df.to_csv("raw_data.csv", index=False)

#Extract data from the raw_data.csv file
extracted_data = extract(file_name="raw_data.csv")
#Transform the extracted_data
transformed_data = transform(data_frame=extracted_data)
#Load the transformed_data to cleaned_data.csv
Load(data_frame=transformed_data, target_table="cleaned_data")
# Out:
# Extracting data from raw_data.csv
# Transforming data...
# Loading data to cleaned_data.csv...
# Data loaded successfully.

# %%
def transform(data_frame):
    print("Transforming data...")
    # Placeholder: Implement your data transformation logic here
    # For now, let's just return the dataframe as is
    return data_frame

def Load(data_frame, target_table):
    print(f"Loading data to {target_table}.csv...")
    # Placeholder: Implement your data loading logic here
    # For now, let's save the dataframe to a CSV file
    data_frame.to_csv(f"{target_table}.csv", index=False)
    print("Data loaded successfully.")

# %%
# Extract data from the raw_data.csv file
raw_data = extract (file_name="raw_data.csv")

# Load the extracted_data to the raw_data table (staging step)
Load(data_frame=raw_data, target_table="raw_data")

# Transform data from the extracted raw_data
transformed_data = transform(data_frame=raw_data)

# Load the transformed_data to the cleaned_data table
Load(data_frame=transformed_data, target_table="cleaned_data")
# Out:
# Extracting data from raw_data.csv
# Loading data to raw_data.csv...
# Data loaded successfully.
# Transforming data...
# Loading data to cleaned_data.csv...
# Data loaded successfully.
